# %%
import matplotlib.pyplot as plt
from plotly.express import scatter_matrix
from sklearn import datasets
from sklearn.metrics import accuracy_score

# %%
iris_dataset = datasets.load_iris()

# %%
print(iris_dataset.data[:2])
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]]

# %%
x= iris_dataset.data[:,:2]

# %%
x_count = len(x.flat)
print(x)
# Out:
# [[5.1 3.5]
#  [4.9 3. ]
#  [4.7 3.2]
#  [4.6 3.1]
#  [5.  3.6]
#  [5.4 3.9]
#  [4.6 3.4]
#  [5.  3.4]
#  [4.4 2.9]
#  [4.9 3.1]
#  [5.4 3.7]
#  [4.8 3.4]
#  [4.8 3. ]
#  [4.3 3. ]
#  [5.8 4. ]
#  [5.7 4.4]
#  [5.4 3.9]
#  [5.1 3.5]
#  [5.7 3.8]
#  [5.1 3.8]
#  [5.4 3.4]
#  [5.1 3.7]
#  [4.6 3.6]
#  [5.1 3.3]
#  [4.8 3.4]
#  [5.  3. ]
#  [5.  3.4]
#  [5.2 3.5]
#  [5.2 3.4]
#  [4.7 3.2]
#  [4.8 3.1]
#  [5.4 3.4]
#  [5.2 4.1]
#  [5.5 4.2]
#  [4.9 3.1]
#  [5.  3.2]
#  [5.5 3.5]
#  [4.9 3.6]
#  [4.4 3. ]
#  [5.1 3.4]
#  [5.  3.5]
#  [4.5 2.3]
#  [4.4 3.2]
#  [5.  3.5]
#  [5.1 3.8]
#  [4.8 3. ]
#  [5.1 3.8]
#  [4.6 3.2]
#  [5.3 3.7]
#  [5.  3.3]
#  [7.  3.2]
#  [6.4 3.2]
#  [6.9 3.1]
#  [5.5 2.3]
#  [6.5 2.8]
#  [5.7 2.8]
#  [6.3 3.3]
#  [4.9 2.4]
#  [6.6 2.9]
#  [5.2 2.7]
#  [5.  2. ]
#  [5.9 3. ]
#  [6.  2.2]
#  [6.1 2.9]
#  [5.6 2.9]
#  [6.7 3.1]
#  [5.6 3. ]
#  [5.8 2.7]
#  [6.2 2.2]
#  [5.6 2.5]
#  [5.9 3.2]
#  [6.1 2.8]
#  [6.3 2.5]
#  [6.1 2.8]
#  [6.4 2.9]
#  [6.6 3. ]
# ...

# %%
x_min = x[:, 0].min() -.5
x_max = x[:, 0].max() +.5
x_mean = x[:, 0].mean()
x_std = x[:, 0].std()
#print(x_min, x_max, x_mean, x_std)
print(x_min)
print(x_max)
print(x_mean)
print(x_std)
# Out:
# 3.8
# 8.4
# 5.843333333333334
# 0.8253012917851409

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# %%
import pandas as pd
name = ['sapel-lenght', 'sapel-width', 'petal-length', 'petal-width','class']
datasets = pd.read_csv(url, names=name)
print(datasets)
# Out:
#      sapel-lenght  sapel-width  petal-length  petal-width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
print(datasets.head(30))
# Out:
#     sapel-lenght  sapel-width  petal-length  petal-width        class
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
print(datasets.groupby('class').size())
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
import matplotlib as plt
datasets.plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False)
# Out:
# sapel-lenght       Axes(0.125,0.53;0.352273x0.35)
# sapel-width     Axes(0.547727,0.53;0.352273x0.35)
# petal-length       Axes(0.125,0.11;0.352273x0.35)
# petal-width     Axes(0.547727,0.11;0.352273x0.35)
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
datasets.hist()
plt.show()

# %%
# multivariable plot
from pandas.plotting import scatter_matrix
scatter_matrix(datasets)
plt.show()

# %%
from sklearn import model_selection
array = datasets.values
x=array[:,0:4]
y=array[:,4]
validation_size = 0.20
seed = 6
x_train,x_test, y_train, y_test = model_selection.train_test_split(x,y,test_size=validation_size,random_state=seed)

# %%
seed = 6
scoring = 'accuracy'
1.10.22
